# %% [markdown]
# ## Upload dataset

# %%
import pandas as pd 
train=pd.read_csv('../input/nlp-getting-started/train.csv')
test=pd.read_csv('../input/nlp-getting-started/test.csv')
print("the shape of our train set rows {} and columns {}".format(train.shape[0],train.shape[1]))
print("the shape of our test set rows {} and columns {}".format(test.shape[0],test.shape[1]))
# Out:
# the shape of our train set rows 7613 and columns 5
# the shape of our test set rows 3263 and columns 4

# %%
train.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test.head(5)
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
#We can see an example of text tweet 
train.text[564]
# Out:
# 'I liked a @YouTube video http://t.co/9Vw0uQQi1y Marvel VS DC (Avengers Battle!)'

# %% [markdown]
# ## Exploratory data

# %%
import matplotlib.pyplot as plt
target=train.target
a=target.value_counts()
import matplotlib.pyplot as plt

to_plot = train.target

fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot()

ax.hist(to_plot)

ax.set_title("Data Distribution " , fontsize = 20)

ax.set_xlabel("Target")

ax.set_ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')

# %% [markdown]
# ## See the most words in corpus

# %%
#We create a corpus represent our words intext tweets
corpus=[]
for x in train.text.str.split():
    for i in x:
       corpus.append(i)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Visualisation part

# %%
## see the frequence of words in the corpus 
nltk.download('stopwords')
from nltk.corpus import stopwords
from collections import defaultdict
stop=set(stopwords.words('english'))
dic=defaultdict(int)
for word in corpus:
    if word not in stop:
        dic[word]+=1
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Remove number punctuation...

# %% [markdown]
# import re
# def  clean_text(df, text_field, new_text_field_name):
#     df[new_text_field_name] = df[text_field].str.lower() #Convert strings in the Series/Index to lowercase.
#
#     # remove numbers
#     df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
#     #remove url
#     df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"https?://\S+|www\.\S+", "", elem))
#     #remove HTML tags
#     df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"<.*?>", "", elem))
#     #remove emojis
#     df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"["
#                            u"\U0001F600-\U0001F64F"  # emoticons
#                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
#                            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                            u"\U00002702-\U000027B0"
#                            u"\U000024C2-\U0001F251"
#                            "]+", "", elem))
#     return df
# train = clean_text(train, 'text', 'text_clean')

# %% [markdown]
# import re
# train['text_clean'] = train['text'].str.lower()
# #Remove URL
# train['text_clean'] =train['text_clean'].apply(lambda x :re.sub(r'http\S+', '',x)) #\S+ means “a string of non-whitespace characters
# train['text_clean'] =train['text_clean'].apply(lambda x :re.sub(r'\d+', '',x))#\d+ means one or more digit [0-9] (depending on LOCALE)
# train['text_clean'] =train['text_clean'].apply(lambda x :re.sub(r"<.*?>", "", x))
# train['text_clean'] =train['text_clean'].apply(lambda x: re.sub(r"["
#                        u"\U0001F600-\U0001F64F"  # emoticons
#                        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#                        u"\U0001F680-\U0001F6FF"  # transport & map symbols
#                        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                        u"\U00002702-\U000027B0"
#                        u"\U000024C2-\U0001F251"
#                        "]+", "", x))

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower() #Convert strings in the Series/Index to lowercase.
    
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    #remove url
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"https?://\S+|www\.\S+", "", elem))
    #remove HTML tags
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"<.*?>", "", elem))
    #remove emojis 
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", "", elem))
    return df
data_clean = clean_text(train, 'text', 'text_clean')
data_clean_test = clean_text(test,'text', 'text_clean')
data_clean.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1  our deeds are the reason of this #earthquake m...
# 1       1             forest fire near la ronge sask. canada
# 2       1  all residents asked to 'shelter in place' are ...
# 3       1  , people receive #wildfires evacuation orders ...
# 4       1  just got sent this photo from ruby #alaska as ...

# %% [markdown]
# ## Remove stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
data_clean['text_clean'] = data_clean['text_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1      deeds reason #earthquake may allah forgive us
# 1       1             forest fire near la ronge sask. canada
# 2       1  residents asked 'shelter place' notified offic...
# 3       1  , people receive #wildfires evacuation orders ...
# 4       1  got sent photo ruby #alaska smoke #wildfires p...

# %%
train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#                                              text_clean
# 0         deeds reason #earthquake may allah forgive us
# 1                forest fire near la ronge sask. canada
# 2     residents asked 'shelter place' notified offic...
# 3     , people receive #wildfires evacuation orders ...
# 4     got sent photo ruby #alaska smoke #wildfires p...
# ...                                                 ...
# 7608  two giant cranes holding bridge collapse nearb...
# 7609  @aria_ahrary @thetawniest control wild fires c...
# 7610                      m. [: utc]?km volcano hawaii.
# 7611  police investigating e-bike collided car littl...
# 7612  latest: homes razed northern california wildfi...
#
# [7613 rows x 6 columns]

# %% [markdown]
# ## Tokenize

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_clean'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean  \
# 0       1      deeds reason #earthquake may allah forgive us
# 1       1             forest fire near la ronge sask. canada
# 2       1  residents asked 'shelter place' notified offic...
# 3       1  , people receive #wildfires evacuation orders ...
# 4       1  got sent photo ruby #alaska smoke #wildfires p...
#
#                                          text_tokens
# 0  [deeds, reason, #, earthquake, may, allah, for...
# 1   [forest, fire, near, la, ronge, sask, ., canada]
# 2  [residents, asked, 'shelter, place, ', notifie...
# 3  [,, people, receive, #, wildfires, evacuation,...
# 4  [got, sent, photo, ruby, #, alaska, smoke, #, ...

# %% [markdown]
# ## Lemmatizing

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return lem_text
data_clean['text_lemmatized'] = data_clean['text_tokens'].apply(lambda x: word_lemmatizer(x))
data_clean.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean  \
# 0       1      deeds reason #earthquake may allah forgive us
# 1       1             forest fire near la ronge sask. canada
# 2       1  residents asked 'shelter place' notified offic...
# 3       1  , people receive #wildfires evacuation orders ...
# 4       1  got sent photo ruby #alaska smoke #wildfires p...
#
#                                          text_tokens  \
# 0  [deeds, reason, #, earthquake, may, allah, for...
# 1   [forest, fire, near, la, ronge, sask, ., canada]
# 2  [residents, asked, 'shelter, place, ', notifie...
# 3  [,, people, receive, #, wildfires, evacuation,...
# 4  [got, sent, photo, ruby, #, alaska, smoke, #, ...
#
#                                    text_clean_tokens  \
# 0  [deed, reason, #, earthquake, may, allah, forg...
# 1   [forest, fire, near, la, ronge, sask, ., canada]
# 2  [resident, asked, 'shelter, place, ', notified...
# 3  [,, people, receive, #, wildfire, evacuation, ...
# 4  [got, sent, photo, ruby, #, alaska, smoke, #, ...
#
#                                      text_lemmatized
# 0  [deed, reason, #, earthquake, may, allah, forg...
# 1   [forest, fire, near, la, ronge, sask, ., canada]
# 2  [resident, asked, 'shelter, place, ', notified...
# 3  [,, people, receive, #, wildfire, evacuation, ...
# 4  [got, sent, photo, ruby, #, alaska, smoke, #, ...

# %% [markdown]
# ## Defining train set

# %%
import numpy as np
#First defining the X (input), and the y (output)
y_train = train['target'].values
X_train = np.array(train["text_lemmatized"])

# %% [markdown]
# ## Bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 2))
vectorized = vectorizer.fit_transform(X_train)
pd.DataFrame(vectorized.toarray(), 
            index=['sentence '+str(i) 
                   for i in range(0, len(X_train))],
            columns=vectorizer.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-90464d56af73> in <module>
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 2))
# ----> 3 vectorized = vectorizer.fit_transform(X_train)
#       4 pd.DataFrame(vectorized.toarray(),
#       5             index=['sentence '+str(i)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1197
#    1198         vocabulary, X = self._count_vocab(raw_documents,
# -> 1199                                           self.fixed_vocabulary_)
#    1200
#    1201         if self.binary:
#
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1108         for doc in raw_documents:
#    1109             feature_counter = {}
# -> 1110             for feature in analyze(doc):
#    1111                 try:
#    1112                     feature_idx = vocabulary[feature]
#
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     102     else:
#     103         if preprocessor is not None:
# --> 104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
#     106             doc = tokenizer(doc)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      67     """
#      68     if lower:
# ---> 69         doc = doc.lower()
#      70     if accent_function is not None:
#      71         doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'
